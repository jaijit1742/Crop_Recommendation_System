# %% [markdown]
# # Export Processed Data

# %%
output_path = 'Dataset/Processed/processed_crop_data.csv'
df.to_csv(output_path, index=False)
print('Processed dataset saved to:', output_path)
print('Final shape:', df.shape)

# %%
df.head()
