# %% [markdown]
# # Display Processed Data

# %%
import pandas as pd

df = pd.read_csv('Dataset/Processed/processed_crop_data.csv')

print('First few rows of the processed dataset:')
print(df.head())

# %%
df.head()

# %%
print('Processed Dataset Shape:', df.shape)

# %%
print('Columns:')
print(df.columns)

# %%
print('Dataset Information:')
df.info()

# %%
print('Statistical Summary:')
print(df.describe())
